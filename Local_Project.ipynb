# %% [markdown]
# We need:
#
#
# 1.   Document Collection (https://github.com/federicarollo/Italian-Crime-News)
# 2.   Test Queries
# 3.   Prejudged Assessments on the Queries

# %% [markdown]
# We have to
# *   Build a parser - Ula
# *   Build a preprocessor - Viktor
# *   Build the data structures (lexicon, docIndex,statistics,directIndex,inverseIndex) - Mateusz
# *   Implement a Ranking Strategy - Ala
# *   Find qrels
# *   Evaluate

# %%
# !pip install -q python-terrier

# %%
from tqdm.auto import tqdm
import pyterrier as pt
import numpy as np
import nltk
import string
from collections import Counter, defaultdict
import re
import pickle
import os, humanize
import time

# %%
nltk.download("stopwords", quiet=True)
stopwords = set(nltk.corpus.stopwords.words("english"))
stemmer = nltk.stem.PorterStemmer().stem

acronym_re = re.compile(r"\.(?!(\S))")
punctuation_wo_dot = string.punctuation.replace(".", "")
trans_table = str.maketrans(
    "‘’´“”–-" + punctuation_wo_dot, "'''\"\"--" + " " * len(punctuation_wo_dot)
)


def preprocess(s):
    # lowercasing
    s = s.lower()
    # ampersand
    s = s.replace("&", " and ")
    # acronyms
    s = acronym_re.sub("", s)
    # remove punctuation and handle special chars
    s = s.translate(trans_table)
    # tokeniser
    s = s.split()
    # stopwords
    s = filter(lambda t: t not in stopwords, s)
    # stemming
    return list(map(stemmer, s))

# %%
dataset = pt.get_dataset("msmarco_passage")
queries = dataset.get_topics("test-2020")
qrels = dataset.get_qrels("test-2020")

dataset.get_corpus()
# Out:
# Java started (triggered by _read_topics_singleline) and loaded: pyterrier.java, pyterrier.terrier.java [version=5.10 (build: craigm 2024-08-22 17:33), helper_version=0.0.8]
# ['C:\\Users\\USER/.pyterrier\\corpora\\msmarco_passage\\corpus\\collection.tsv']

# %%
DOCS = 0
for _ in dataset.get_corpus_iter():
    DOCS += 1

# %%
def defaultlexicon():
    return [0, 0]


def build_index(docs):

    lexicon = defaultdict(defaultlexicon)  # token -> df, tf
    docids = defaultdict(list)  # token -> list of docids
    freqs = defaultdict(list)  # token -> list of frequencies in each doc
    doc_index = {}  # docno -> size of document, length normalization component

    doc_len_sum = 0

    for doc in tqdm(docs.get_corpus_iter(), total=DOCS):
        docid = doc["docno"]
        tokens = preprocess(doc["text"])
        token_tf = Counter(tokens)
        doc_index[docid] = (len(tokens), 0)
        doc_len_sum += len(tokens)

        for token, tf in token_tf.items():
            lexicon[token][0] += 1
            lexicon[token][1] += tf
            docids[token].append(docid)
            freqs[token].append(tf)

    stats = {
        "num_docs": int(docid),
        "num_terms": len(lexicon),
        "avg_doc_len": doc_len_sum / DOCS,
    }
    return {
        "lexicon": lexicon,
        "docids": docids,
        "freqs": freqs,
        "doc_index": doc_index,
        "stats": stats,
    }

# %%
if not os.path.exists("index.pickle"):
    index = build_index(dataset)
    # update length normalisation components in doc_index
    b = 0.75
    for docid, (doc_len, _) in tqdm(index["doc_index"].items(), total=DOCS):
        index["doc_index"][docid] = (
            doc_len,
            (1 - b) + b * (doc_len / index["stats"]["avg_doc_len"]),
        )
    with open("index.pickle", "wb") as f:
        pickle.dump(index, f)
    print(
        f'The index requires {humanize.naturalsize(os.path.getsize("index.pickle"))} bytes'
    )
else:
    with open("index.pickle", "rb") as f:
        index = pickle.load(f)
    print(f"Loaded index with {index['stats']['num_docs']} documents")
# Out:
#   0%|          | 0/8841823 [00:00<?, ?it/s]
#   0%|          | 0/8841823 [00:00<?, ?it/s]
# The index requires 1.9 GB bytes

# %%
#  BM25 ranking function
def bm25_ranking(query, index: dict, k=1.5, b=0.75):
    query_tokens = preprocess(query)
    scores = defaultdict(float)

    for token in query_tokens:
        if token in index["lexicon"]:
            doc_freq = len(index["docids"][token])
            for doc_id, tf in zip(index["docids"][token], index["freqs"][token]):
                idf = np.log(index["stats"]["num_docs"] / doc_freq)
                numerator = tf
                denominator = tf + k * index["doc_index"][doc_id][1]
                bm25_score = idf * (numerator / denominator)

                scores[doc_id] += bm25_score

    ranked_docs = sorted(scores.items(), key=lambda item: item[1], reverse=True)
    return ranked_docs

# %%
def ndcg_at_k(r, k):
    def dcg_at_k(r, k):
        r = np.asarray(r)[:k]
        return sum(r[i] / max(1, np.log2(i + 1)) for i in range(0, k))

    idcg = dcg_at_k(sorted(r, reverse=True), k)
    if not idcg:
        return 0.0
    return dcg_at_k(r, k) / idcg

# %%
def ap_at_k(r, k):
    r = np.asarray(r)[:k] != 0
    N = sum(r)
    if N == 0:
        return 0
    return sum([sum(r[: i + 1]) / (i + 1) * r[i] for i in range(k)]) / N

# %%
def benchmark(timing=True, evaluate=True):
    ndcg_at_10 = []
    aps_at_10 = []

    art = 0  # average ranking time

    for i, query in tqdm(queries.iterrows(), total=len(queries)):
        start = time.time()
        results = bm25_ranking(query["query"], index)
        if timing:
            end = time.time()
            art = (i * art + end - start) / (i + 1)
            print(f"Ranking time:\t\t{end-start:.5f}")
            print(f"Average ranking time:\t{art:.5f}")

        if evaluate:
            rel_qrels = qrels[qrels["qid"] == query["qid"]].set_index("docno")
            relevance_judgments = [
                rel_qrels["label"].get(docno, 0) for docno, _ in results
            ]

            ndcg_at_10.append(ndcg_at_k(relevance_judgments, 10))
            aps_at_10.append(ap_at_k(relevance_judgments, 10))
            print("")
            print(f"nDCG@10:\t\t{ndcg_at_10[-1]:.5f}")
            print(f"AP@10:\t\t\t{aps_at_10[-1]:.5f}")
        print("----------------------------------------------------------")
    if evaluate:
        print(f"Mean nDCG @ 10:\t\t\t{ np.mean(ndcg_at_10):.5f}")
        print(f"Mean Average Precision @ 10:\t{np.mean(aps_at_10):.5f}")

# %%
benchmark(timing=True, evaluate=False)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Ranking time:		0.01200
# Average ranking time:	0.01200
# ----------------------------------------------------------
# Ranking time:		0.01900
# Average ranking time:	0.01550
# ----------------------------------------------------------
# Ranking time:		0.24781
# Average ranking time:	0.09294
# ----------------------------------------------------------
# Ranking time:		0.10300
# Average ranking time:	0.09545
# ----------------------------------------------------------
# Ranking time:		4.42046
# Average ranking time:	0.96045
# ----------------------------------------------------------
# Ranking time:		0.41500
# Average ranking time:	0.86955
# ----------------------------------------------------------
# Ranking time:		0.85951
# Average ranking time:	0.86811
# ----------------------------------------------------------
# Ranking time:		0.16600
# Average ranking time:	0.78035
# ----------------------------------------------------------
# Ranking time:		0.98475
# Average ranking time:	0.80306
# ----------------------------------------------------------
# Ranking time:		0.19800
# Average ranking time:	0.74255
# ----------------------------------------------------------
# Ranking time:		0.04800
# Average ranking time:	0.67941
# ----------------------------------------------------------
# Ranking time:		0.47700
# Average ranking time:	0.66254
# ----------------------------------------------------------
# Ranking time:		1.75024
# Average ranking time:	0.74621
# ----------------------------------------------------------
# Ranking time:		0.32826
# Average ranking time:	0.71636
# ----------------------------------------------------------
# Ranking time:		0.73400
# Average ranking time:	0.71754
# ----------------------------------------------------------
# Ranking time:		0.96905
# Average ranking time:	0.73326
# ----------------------------------------------------------
# Ranking time:		0.52228
# Average ranking time:	0.72084
# ----------------------------------------------------------
# Ranking time:		2.50896
# Average ranking time:	0.82018
# ----------------------------------------------------------
# Ranking time:		2.56872
# Average ranking time:	0.91221
# ----------------------------------------------------------
# Ranking time:		0.55764
# Average ranking time:	0.89448
# ----------------------------------------------------------
# Ranking time:		0.30530
# Average ranking time:	0.86643
# ----------------------------------------------------------
# Ranking time:		2.05521
# Average ranking time:	0.92046
# ----------------------------------------------------------
# Ranking time:		3.08144
# Average ranking time:	1.01442
# ----------------------------------------------------------
# Ranking time:		0.82833
# Average ranking time:	1.00667
# ----------------------------------------------------------
# Ranking time:		0.19500
# Average ranking time:	0.97420
# ----------------------------------------------------------
# Ranking time:		0.47995
# Average ranking time:	0.95519
# ----------------------------------------------------------
# Ranking time:		0.37360
# Average ranking time:	0.93365
# ----------------------------------------------------------
# Ranking time:		0.03933
# Average ranking time:	0.90171
# ----------------------------------------------------------
# Ranking time:		0.45000
# Average ranking time:	0.88613
# ----------------------------------------------------------
# Ranking time:		1.04787
# Average ranking time:	0.89152
# ----------------------------------------------------------
# Ranking time:		0.25439
# Average ranking time:	0.87097
# ----------------------------------------------------------
# Ranking time:		2.05273
# Average ranking time:	0.90790
# ----------------------------------------------------------
# Ranking time:		0.65500
# Average ranking time:	0.90024
# ----------------------------------------------------------
# Ranking time:		0.53482
# Average ranking time:	0.88949
# ----------------------------------------------------------
# Ranking time:		0.03600
# Average ranking time:	0.86510
# ----------------------------------------------------------
# Ranking time:		0.30900
# Average ranking time:	0.84966
# ----------------------------------------------------------
# Ranking time:		1.39208
# Average ranking time:	0.86432
# ----------------------------------------------------------
# Ranking time:		1.35319
# Average ranking time:	0.87718
# ----------------------------------------------------------
# Ranking time:		0.96584
# Average ranking time:	0.87946
# ----------------------------------------------------------
# Ranking time:		1.12654
# Average ranking time:	0.88563
# ----------------------------------------------------------
# Ranking time:		0.91196
# Average ranking time:	0.88627
# ----------------------------------------------------------
# Ranking time:		0.63413
# Average ranking time:	0.88027
# ----------------------------------------------------------
# Ranking time:		0.89941
# Average ranking time:	0.88072
# ----------------------------------------------------------
# Ranking time:		0.63093
# Average ranking time:	0.87504
# ----------------------------------------------------------
# Ranking time:		1.85532
# Average ranking time:	0.89682
# ----------------------------------------------------------
# Ranking time:		0.59600
# Average ranking time:	0.89028
# ----------------------------------------------------------
# Ranking time:		0.58700
# Average ranking time:	0.88383
# ----------------------------------------------------------
# Ranking time:		2.21260
# Average ranking time:	0.91151
# ----------------------------------------------------------
# Ranking time:		1.17127
# Average ranking time:	0.91682
# ----------------------------------------------------------
# Ranking time:		0.76346
# Average ranking time:	0.91375
# ----------------------------------------------------------
# Ranking time:		1.79280
# Average ranking time:	0.93098
# ----------------------------------------------------------
# Ranking time:		0.56035
# Average ranking time:	0.92386
# ----------------------------------------------------------
# Ranking time:		0.49200
# Average ranking time:	0.91571
# ----------------------------------------------------------
# Ranking time:		1.31071
# Average ranking time:	0.92302
# ----------------------------------------------------------
# Ranking time:		0.52391
# Average ranking time:	0.91577
# ----------------------------------------------------------
# Ranking time:		0.91600
# Average ranking time:	0.91577
# ----------------------------------------------------------
# Ranking time:		0.91984
# Average ranking time:	0.91584
# ----------------------------------------------------------
# Ranking time:		0.26300
# Average ranking time:	0.90459
# ----------------------------------------------------------
# Ranking time:		0.24256
# Average ranking time:	0.89337
# ----------------------------------------------------------
# Ranking time:		0.69821
# Average ranking time:	0.89011
# ----------------------------------------------------------
# Ranking time:		1.82027
# Average ranking time:	0.90536
# ----------------------------------------------------------
# Ranking time:		4.45847
# Average ranking time:	0.96267
# ----------------------------------------------------------
# Ranking time:		1.44116
# Average ranking time:	0.97026
# ----------------------------------------------------------
# Ranking time:		2.01501
# Average ranking time:	0.98659
# ----------------------------------------------------------
# Ranking time:		1.20500
# Average ranking time:	0.98995
# ----------------------------------------------------------
# Ranking time:		1.63726
# Average ranking time:	0.99976
# ----------------------------------------------------------
# Ranking time:		0.92000
# Average ranking time:	0.99857
# ----------------------------------------------------------
# Ranking time:		0.91411
# Average ranking time:	0.99732
# ----------------------------------------------------------
# Ranking time:		1.37328
# Average ranking time:	1.00277
# ----------------------------------------------------------
# Ranking time:		1.38896
# Average ranking time:	1.00829
# ----------------------------------------------------------
# Ranking time:		0.91329
# Average ranking time:	1.00695
# ----------------------------------------------------------
# Ranking time:		0.36200
# Average ranking time:	0.99799
# ----------------------------------------------------------
# Ranking time:		0.57500
# Average ranking time:	0.99220
# ----------------------------------------------------------
# Ranking time:		0.46048
# Average ranking time:	0.98501
# ----------------------------------------------------------
# Ranking time:		0.76500
# Average ranking time:	0.98208
# ----------------------------------------------------------
# Ranking time:		0.49300
# Average ranking time:	0.97565
# ----------------------------------------------------------
# Ranking time:		2.62668
# Average ranking time:	0.99709
# ----------------------------------------------------------
# Ranking time:		0.65200
# Average ranking time:	0.99266
# ----------------------------------------------------------
# Ranking time:		0.69795
# Average ranking time:	0.98893
# ----------------------------------------------------------
# Ranking time:		0.44400
# Average ranking time:	0.98212
# ----------------------------------------------------------
# Ranking time:		1.61347
# Average ranking time:	0.98992
# ----------------------------------------------------------
# Ranking time:		1.03788
# Average ranking time:	0.99050
# ----------------------------------------------------------
# Ranking time:		2.18655
# Average ranking time:	1.00491
# ----------------------------------------------------------
# Ranking time:		0.12700
# Average ranking time:	0.99446
# ----------------------------------------------------------
# Ranking time:		1.71961
# Average ranking time:	1.00299
# ----------------------------------------------------------
# Ranking time:		0.89100
# Average ranking time:	1.00169
# ----------------------------------------------------------
# Ranking time:		0.26800
# Average ranking time:	0.99325
# ----------------------------------------------------------
# Ranking time:		0.24124
# Average ranking time:	0.98471
# ----------------------------------------------------------
# Ranking time:		0.47924
# Average ranking time:	0.97903
# ----------------------------------------------------------
# Ranking time:		0.47587
# Average ranking time:	0.97344
# ----------------------------------------------------------
# Ranking time:		2.60760
# Average ranking time:	0.99140
# ----------------------------------------------------------
# Ranking time:		0.64400
# Average ranking time:	0.98762
# ----------------------------------------------------------
# Ranking time:		0.39500
# Average ranking time:	0.98125
# ----------------------------------------------------------
# Ranking time:		0.70951
# Average ranking time:	0.97836
# ----------------------------------------------------------
# Ranking time:		0.56100
# Average ranking time:	0.97396
# ----------------------------------------------------------
# Ranking time:		2.30866
# Average ranking time:	0.98787
# ----------------------------------------------------------
# Ranking time:		0.50400
# Average ranking time:	0.98288
# ----------------------------------------------------------
# Ranking time:		1.33854
# Average ranking time:	0.98651
# ----------------------------------------------------------
# Ranking time:		0.95923
# Average ranking time:	0.98623
# ----------------------------------------------------------
# Ranking time:		0.87986
# Average ranking time:	0.98517
# ----------------------------------------------------------
# Ranking time:		0.97300
# Average ranking time:	0.98505
# ----------------------------------------------------------
# Ranking time:		0.97185
# Average ranking time:	0.98492
# ----------------------------------------------------------
# Ranking time:		1.91549
# Average ranking time:	0.99395
# ----------------------------------------------------------
# Ranking time:		1.03000
# Average ranking time:	0.99430
# ----------------------------------------------------------
# Ranking time:		2.05283
# Average ranking time:	1.00438
# ----------------------------------------------------------
# Ranking time:		1.34000
# Average ranking time:	1.00755
# ----------------------------------------------------------
# Ranking time:		2.27583
# Average ranking time:	1.01940
# ----------------------------------------------------------
# Ranking time:		4.09273
# Average ranking time:	1.04786
# ----------------------------------------------------------
# Ranking time:		3.27009
# Average ranking time:	1.06825
# ----------------------------------------------------------
# Ranking time:		2.44551
# Average ranking time:	1.08077
# ----------------------------------------------------------
# Ranking time:		0.69000
# Average ranking time:	1.07725
# ----------------------------------------------------------
# Ranking time:		1.69429
# Average ranking time:	1.08275
# ----------------------------------------------------------
# Ranking time:		0.98900
# Average ranking time:	1.08192
# ----------------------------------------------------------
# Ranking time:		3.85719
# Average ranking time:	1.10627
# ----------------------------------------------------------
# Ranking time:		2.51668
# Average ranking time:	1.11853
# ----------------------------------------------------------
# Ranking time:		1.18266
# Average ranking time:	1.11909
# ----------------------------------------------------------
# Ranking time:		2.38031
# Average ranking time:	1.12987
# ----------------------------------------------------------
# Ranking time:		1.05000
# Average ranking time:	1.12919
# ----------------------------------------------------------
# Ranking time:		0.44550
# Average ranking time:	1.12344
# ----------------------------------------------------------
# Ranking time:		0.88468
# Average ranking time:	1.12145
# ----------------------------------------------------------
# Ranking time:		4.51986
# Average ranking time:	1.14954
# ----------------------------------------------------------
# Ranking time:		1.28291
# Average ranking time:	1.15063
# ----------------------------------------------------------
# Ranking time:		0.98190
# Average ranking time:	1.14926
# ----------------------------------------------------------
# Ranking time:		0.08100
# Average ranking time:	1.14065
# ----------------------------------------------------------
# Ranking time:		1.01293
# Average ranking time:	1.13963
# ----------------------------------------------------------
# Ranking time:		0.06300
# Average ranking time:	1.13108
# ----------------------------------------------------------
# Ranking time:		0.26109
# Average ranking time:	1.12423
# ----------------------------------------------------------
# Ranking time:		1.06668
# Average ranking time:	1.12378
# ----------------------------------------------------------
# Ranking time:		0.64398
# Average ranking time:	1.12006
# ----------------------------------------------------------
# Ranking time:		0.97900
# Average ranking time:	1.11898
# ----------------------------------------------------------
# Ranking time:		0.57100
# Average ranking time:	1.11479
# ----------------------------------------------------------
# Ranking time:		1.73725
# Average ranking time:	1.11951
# ----------------------------------------------------------
# Ranking time:		1.28160
# Average ranking time:	1.12073
# ----------------------------------------------------------
# Ranking time:		0.36644
# Average ranking time:	1.11510
# ----------------------------------------------------------
# Ranking time:		0.81387
# Average ranking time:	1.11287
# ----------------------------------------------------------
# Ranking time:		1.59338
# Average ranking time:	1.11640
# ----------------------------------------------------------
# Ranking time:		0.83790
# Average ranking time:	1.11437
# ----------------------------------------------------------
# Ranking time:		0.87600
# Average ranking time:	1.11264
# ----------------------------------------------------------
# Ranking time:		0.47632
# Average ranking time:	1.10806
# ----------------------------------------------------------
# Ranking time:		0.74134
# Average ranking time:	1.10544
# ----------------------------------------------------------
# Ranking time:		0.48200
# Average ranking time:	1.10102
# ----------------------------------------------------------
# Ranking time:		0.17400
# Average ranking time:	1.09449
# ----------------------------------------------------------
# Ranking time:		0.07970
# Average ranking time:	1.08740
# ----------------------------------------------------------
# Ranking time:		0.45228
# Average ranking time:	1.08299
# ----------------------------------------------------------
# Ranking time:		0.33027
# Average ranking time:	1.07779
# ----------------------------------------------------------
# Ranking time:		0.23461
# Average ranking time:	1.07202
# ----------------------------------------------------------
# Ranking time:		1.59352
# Average ranking time:	1.07557
# ----------------------------------------------------------
# Ranking time:		3.31324
# Average ranking time:	1.09069
# ----------------------------------------------------------
# Ranking time:		1.62169
# Average ranking time:	1.09425
# ----------------------------------------------------------
# Ranking time:		1.41278
# Average ranking time:	1.09637
# ----------------------------------------------------------
# Ranking time:		0.46886
# Average ranking time:	1.09222
# ----------------------------------------------------------
# Ranking time:		2.88171
# Average ranking time:	1.10399
# ----------------------------------------------------------
# Ranking time:		0.51063
# Average ranking time:	1.10011
# ----------------------------------------------------------
# Ranking time:		1.34823
# Average ranking time:	1.10172
# ----------------------------------------------------------
# Ranking time:		1.09397
# Average ranking time:	1.10167
# ----------------------------------------------------------
# Ranking time:		1.20800
# Average ranking time:	1.10236
# ----------------------------------------------------------
# Ranking time:		0.30438
# Average ranking time:	1.09727
# ----------------------------------------------------------
# Ranking time:		0.23200
# Average ranking time:	1.09180
# ----------------------------------------------------------
# Ranking time:		1.59403
# Average ranking time:	1.09496
# ----------------------------------------------------------
# Ranking time:		1.54568
# Average ranking time:	1.09777
# ----------------------------------------------------------
# Ranking time:		0.07700
# Average ranking time:	1.09143
# ----------------------------------------------------------
# Ranking time:		0.02700
# Average ranking time:	1.08486
# ----------------------------------------------------------
# Ranking time:		0.04558
# Average ranking time:	1.07849
# ----------------------------------------------------------
# Ranking time:		0.12156
# Average ranking time:	1.07265
# ----------------------------------------------------------
# Ranking time:		0.00700
# Average ranking time:	1.06619
# ----------------------------------------------------------
# Ranking time:		0.04834
# Average ranking time:	1.06006
# ----------------------------------------------------------
# Ranking time:		0.06200
# Average ranking time:	1.05408
# ----------------------------------------------------------
# Ranking time:		0.24800
# Average ranking time:	1.04929
# ----------------------------------------------------------
# Ranking time:		1.05862
# Average ranking time:	1.04934
# ----------------------------------------------------------
# Ranking time:		0.06300
# Average ranking time:	1.04354
# ----------------------------------------------------------
# Ranking time:		0.34889
# Average ranking time:	1.03948
# ----------------------------------------------------------
# Ranking time:		0.01700
# Average ranking time:	1.03353
# ----------------------------------------------------------
# Ranking time:		0.55455
# Average ranking time:	1.03076
# ----------------------------------------------------------
# Ranking time:		0.41161
# Average ranking time:	1.02721
# ----------------------------------------------------------
# Ranking time:		3.69469
# Average ranking time:	1.04245
# ----------------------------------------------------------
# Ranking time:		0.68800
# Average ranking time:	1.04043
# ----------------------------------------------------------
# Ranking time:		0.88416
# Average ranking time:	1.03955
# ----------------------------------------------------------
# Ranking time:		0.95163
# Average ranking time:	1.03906
# ----------------------------------------------------------
# Ranking time:		0.98785
# Average ranking time:	1.03877
# ----------------------------------------------------------
# Ranking time:		0.41132
# Average ranking time:	1.03529
# ----------------------------------------------------------
# Ranking time:		0.41330
# Average ranking time:	1.03185
# ----------------------------------------------------------
# Ranking time:		1.41662
# Average ranking time:	1.03396
# ----------------------------------------------------------
# Ranking time:		0.43035
# Average ranking time:	1.03066
# ----------------------------------------------------------
# Ranking time:		1.75010
# Average ranking time:	1.03457
# ----------------------------------------------------------
# Ranking time:		1.08700
# Average ranking time:	1.03486
# ----------------------------------------------------------
# Ranking time:		1.42878
# Average ranking time:	1.03698
# ----------------------------------------------------------
# Ranking time:		1.14115
# Average ranking time:	1.03753
# ----------------------------------------------------------
# Ranking time:		1.27611
# Average ranking time:	1.03880
# ----------------------------------------------------------
# Ranking time:		1.18873
# Average ranking time:	1.03960
# ----------------------------------------------------------
# Ranking time:		0.75487
# Average ranking time:	1.03810
# ----------------------------------------------------------
# Ranking time:		0.30700
# Average ranking time:	1.03427
# ----------------------------------------------------------
# Ranking time:		1.03676
# Average ranking time:	1.03428
# ----------------------------------------------------------
# Ranking time:		0.78400
# Average ranking time:	1.03298
# ----------------------------------------------------------
# Ranking time:		0.54865
# Average ranking time:	1.03049
# ----------------------------------------------------------
# Ranking time:		0.38127
# Average ranking time:	1.02716
# ----------------------------------------------------------
# Ranking time:		0.02100
# Average ranking time:	1.02203
# ----------------------------------------------------------
# Ranking time:		0.47500
# Average ranking time:	1.01925
# ----------------------------------------------------------
# Ranking time:		0.72400
# Average ranking time:	1.01776
# ----------------------------------------------------------
# Ranking time:		0.04200
# Average ranking time:	1.01285
# ----------------------------------------------------------
# Ranking time:		0.56600
# Average ranking time:	1.01062
# ----------------------------------------------------------
